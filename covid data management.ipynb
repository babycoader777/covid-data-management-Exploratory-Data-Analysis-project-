# %%
import numpy as np
import pandas as pd
import os
import  matplotlib.pyplot as plt
import seaborn as sns;

# %%
df=pd.read_csv("1.csv")
df
# Out:
#               id        date  confirmed  deaths  recovered      tests  \
# 0       8320791a  2020-03-13        2.0     NaN        NaN        NaN
# 1       8320791a  2020-03-14        2.0     NaN        NaN        NaN
# 2       8320791a  2020-03-15        2.0     NaN        NaN        NaN
# 3       8320791a  2020-03-16        2.0     NaN        NaN        NaN
# 4       8320791a  2020-03-17        8.0     NaN        NaN        NaN
# ...          ...         ...        ...     ...        ...        ...
# 184849  770febbe  2022-04-15   164042.0  3597.0        NaN        NaN
# 184850  770febbe  2022-04-16   164051.0  3597.0        NaN        NaN
# 184851  770febbe  2022-04-17   164051.0  3597.0        NaN        NaN
# 184852  770febbe  2022-04-18   164055.0  3597.0        NaN  2598861.0
# 184853  770febbe  2022-04-19   164058.0  3597.0        NaN        NaN
#
#         vaccines  people_vaccinated  people_fully_vaccinated  hosp  ...  \
# ...

# %%
df.shape
# Out:
# (184854, 47)

# %%
#no of rows
row=df.shape[0]
row
# Out:
# 184854

# %%
#no of columns
col=df.shape[1]
col
# Out:
# 47

# %%
df.describe()
# Out:
#           confirmed         deaths     recovered         tests      vaccines  \
# count  1.685260e+05  152601.000000  7.004300e+04  7.704000e+04  4.674000e+04
# mean   7.075478e+05   14537.796371  5.308972e+05  1.838505e+07  4.567256e+07
# std    3.528100e+06   60709.429452  2.135783e+06  6.892498e+07  2.304848e+08
# min    0.000000e+00       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.187000e+03      65.000000  2.902000e+03  3.174955e+05  2.914940e+05
# 50%    2.241300e+04     585.000000  2.609700e+04  1.792006e+06  2.762962e+06
# 75%    2.354285e+05    4995.000000  2.161175e+05  8.978956e+06  1.555967e+07
# max    8.064553e+07  987999.000000  3.097475e+07  8.600245e+08  3.317463e+09
#
#        people_vaccinated  people_fully_vaccinated           hosp  \
# count       4.446200e+04             4.203700e+04   32172.000000
# mean        1.723407e+07             1.389391e+07    5832.388381
# std         7.207627e+07             5.905647e+07   34001.322057
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184854 entries, 0 to 184853
# Data columns (total 47 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   id                                   184854 non-null  object
#  1   date                                 184854 non-null  object
#  2   confirmed                            168526 non-null  float64
#  3   deaths                               152601 non-null  float64
#  4   recovered                            70043 non-null   float64
#  5   tests                                77040 non-null   float64
#  6   vaccines                             46740 non-null   float64
#  7   people_vaccinated                    44462 non-null   float64
#  8   people_fully_vaccinated              42037 non-null   float64
#  9   hosp                                 32172 non-null   float64
# ...

# %%
# rows and columns with null values
df.isnull()
# Out:
#            id   date  confirmed  deaths  recovered  tests  vaccines  \
# 0       False  False      False    True       True   True      True
# 1       False  False      False    True       True   True      True
# 2       False  False      False    True       True   True      True
# 3       False  False      False    True       True   True      True
# 4       False  False      False    True       True   True      True
# ...       ...    ...        ...     ...        ...    ...       ...
# 184849  False  False      False   False       True   True      True
# 184850  False  False      False   False       True   True      True
# 184851  False  False      False   False       True   True      True
# 184852  False  False      False   False       True  False      True
# 184853  False  False      False   False       True   True      True
#
#         people_vaccinated  people_fully_vaccinated  hosp  ...  iso_alpha_3  \
# ...

# %%
#  count no of null values in each attributes
ld=df.isnull().sum()
ld
# Out:
# id                                          0
# date                                        0
# confirmed                               16328
# deaths                                  32253
# recovered                              114811
# tests                                  107814
# vaccines                               138114
# people_vaccinated                      140392
# people_fully_vaccinated                142817
# hosp                                   152682
# icu                                    154469
# vent                                   179464
# school_closing                          36435
# workplace_closing                       36414
# cancel_events                           36434
# gatherings_restrictions                 36464
# transport_closing                       36456
# stay_home_restrictions                  36500
# internal_movement_restrictions          36481
# international_movement_restrictions     36450
# ...

# %%
#total number of null entries
ne=ld.sum()
ne
# Out:
# 2822270

# %%
# total number of entries
te=row*col
te
# Out:
# 8688138

# %%
#percentage of of null values in our dataset
ne/te
# Out:
# 0.32484175550618555

# %%
# percentage of null entries in each attributes
lp1=((df.isnull().sum())/row)*100
lp1.shape
# Out:
# (47,)

# %%
# we can drop some irrevalent data from our database that doesnot affect our analysis and has large amount of null values
df=df.drop(['administrative_area_level_2','administrative_area_level_3','iso_alpha_3','iso_alpha_2','iso_numeric','iso_currency','key_local','key_google_mobility','key_apple_mobility','key_jhu_csse','key_nuts','key_gadm'], axis = 1)

# %%
# columns after deleting
coln=df.columns
coln
# Out:
# Index(['id', 'date', 'confirmed', 'deaths', 'recovered', 'tests', 'vaccines',
#        'people_vaccinated', 'people_fully_vaccinated', 'hosp', 'icu', 'vent',
#        'school_closing', 'workplace_closing', 'cancel_events',
#        'gatherings_restrictions', 'transport_closing',
#        'stay_home_restrictions', 'internal_movement_restrictions',
#        'international_movement_restrictions', 'information_campaigns',
#        'testing_policy', 'contact_tracing', 'facial_coverings',
#        'vaccination_policy', 'elderly_people_protection',
#        'government_response_index', 'stringency_index',
#        'containment_health_index', 'economic_support_index',
#        'administrative_area_level', 'administrative_area_level_1', 'latitude',
#        'longitude', 'population'],
#       dtype='object')

# %%
#no of columns
col1=df.shape[1]
col1
# Out:
# 35

# %%
# new total number of null entries
ld=df.isnull().sum()
ne1=ld.sum()
ne1
# Out:
# 1843235

# %%
# total number of entries
te1=row*col1
te1
# Out:
# 6469890

# %%
#percentage of of null values in our dataset
ne1/te1
# Out:
# 0.2848943335976346

# %%
# filling  null value using fillna() function  
df=df.fillna(method ='bfill')
df
# Out:
#               id        date  confirmed  deaths  recovered      tests  \
# 0       8320791a  2020-03-13        2.0     0.0        0.0        4.0
# 1       8320791a  2020-03-14        2.0     0.0        0.0        4.0
# 2       8320791a  2020-03-15        2.0     0.0        0.0        4.0
# 3       8320791a  2020-03-16        2.0     0.0        0.0        4.0
# 4       8320791a  2020-03-17        8.0     0.0        0.0        4.0
# ...          ...         ...        ...     ...        ...        ...
# 184849  770febbe  2022-04-15   164042.0  3597.0        NaN  2598861.0
# 184850  770febbe  2022-04-16   164051.0  3597.0        NaN  2598861.0
# 184851  770febbe  2022-04-17   164051.0  3597.0        NaN  2598861.0
# 184852  770febbe  2022-04-18   164055.0  3597.0        NaN  2598861.0
# 184853  770febbe  2022-04-19   164058.0  3597.0        NaN        NaN
#
#         vaccines  people_vaccinated  people_fully_vaccinated  hosp  ...  \
# ...

# %%
# percentage of null values

lp2=((df.isnull().sum())/row)*100
lp2
# Out:
# id                                      0.000000
# date                                    0.000000
# confirmed                               0.000000
# deaths                                  0.000000
# recovered                               0.139570
# tests                                   0.000541
# vaccines                                0.004869
# people_vaccinated                       0.004869
# people_fully_vaccinated                 0.004869
# hosp                                    2.220130
# icu                                     2.220130
# vent                                   20.215413
# school_closing                          0.000541
# workplace_closing                       0.000541
# cancel_events                           0.000541
# gatherings_restrictions                 0.000541
# transport_closing                       0.000541
# stay_home_restrictions                  0.000541
# internal_movement_restrictions          0.000541
# ...

# %%
#  remaining values filling a missing value with
# previous ones  
df=df.fillna(method ='pad')

# %%
# percentage of null values  after all operation

lp3=((df.isnull().sum())/row)*100
lp3
# Out:
# id                                     0.0
# date                                   0.0
# confirmed                              0.0
# deaths                                 0.0
# recovered                              0.0
# tests                                  0.0
# vaccines                               0.0
# people_vaccinated                      0.0
# people_fully_vaccinated                0.0
# hosp                                   0.0
# icu                                    0.0
# vent                                   0.0
# school_closing                         0.0
# workplace_closing                      0.0
# cancel_events                          0.0
# gatherings_restrictions                0.0
# transport_closing                      0.0
# stay_home_restrictions                 0.0
# internal_movement_restrictions         0.0
# international_movement_restrictions    0.0
# information_campaigns                  0.0
# testing_policy                         0.0
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
x1=lp1.index
y1=lp1
x2=lp2.index
y2=lp2
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.bar(x1,y1,label="before cleaning")
plt.xticks(rotation=90)

plt.figure(figsize=(18,5))
plt.subplot(1,2,2)
plt.bar(x2,y2,label="afetr cleaning")
plt.xticks(rotation=90)
plt.show()

# %%
df=df.replace(to_replace =-4,
                 value =4)
df=df.replace(to_replace =-3,
                 value =3)
df=df.replace(to_replace =-2,
                 value =2)
df=df.replace(to_replace =-1,
                 value =1)

# %%
# plot days vs confirmed cases ,deaths and vaccinated  
def get_day(address):
    return address.split('-')[2]

def get_month(address):
    return address.split('-')[1]

def get_year(address):
    return address.split('-')[0]

df['Date'] = df['date'].apply(lambda x: get_year(x)+get_month(x)+get_day(x))


df['year']=df['date'].apply(lambda x: get_year(x) )
df['month']=df['date'].apply(lambda x: get_month(x) )

# %%
# def convftoi(x):
#     return int(x)


# India['C_freqI'] = India['C_freqI'].apply(lambda x: convftoi(x))

# %%
df['Date']=df['Date'].astype(int)
type(df['Date'])
# Out:
# pandas.core.series.Series

# %%
df['year']=df['year'].astype(int)
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
df=df.sort_values(by='Date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184854 entries, 8558 to 94903
# Data columns (total 38 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   id                                   184854 non-null  object
#  1   date                                 184854 non-null  object
#  2   confirmed                            184854 non-null  float64
#  3   deaths                               184854 non-null  float64
#  4   recovered                            184854 non-null  float64
#  5   tests                                184854 non-null  float64
#  6   vaccines                             184854 non-null  float64
#  7   people_vaccinated                    184854 non-null  float64
#  8   people_fully_vaccinated              184854 non-null  float64
#  9   hosp                                 184854 non-null  float64
# ...

# %%
df0 = df[df['year'] == 2020]
df1= df[df['year'] == 2021]
df0.head(7)
# Out:
#               id        date  confirmed  deaths  recovered       tests  \
# 8558    b2f6a333  2020-01-01        1.0     1.0        1.0         4.0
# 125162  3367d334  2020-01-01        1.0     1.0        1.0        25.0
# 8559    b2f6a333  2020-01-02        1.0     1.0        1.0        99.0
# 125163  3367d334  2020-01-02        1.0     1.0        1.0        97.0
# 93250   42079406  2020-01-02        1.0     0.0        1.0    129291.0
# 92412   78833522  2020-01-03        0.0     0.0        1.0  90000000.0
# 8560    b2f6a333  2020-01-03        1.0     1.0        1.0       104.0
#
#          vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# 8558      20491.0            20486.0                      5.0    0.0  ...
# 125162     2924.0             2924.0                   1958.0    0.0  ...
# 8559      20491.0            20486.0                      5.0    0.0  ...
# 125163     2924.0             2924.0                   1958.0    0.0  ...
# ...

# %%
df0.head(55)
# Out:
#               id        date  confirmed  deaths  recovered       tests  \
# 8558    b2f6a333  2020-01-01        1.0     1.0        1.0         4.0
# 125162  3367d334  2020-01-01        1.0     1.0        1.0        25.0
# 8559    b2f6a333  2020-01-02        1.0     1.0        1.0        99.0
# 125163  3367d334  2020-01-02        1.0     1.0        1.0        97.0
# 93250   42079406  2020-01-02        1.0     0.0        1.0    129291.0
# 92412   78833522  2020-01-03        0.0     0.0        1.0  90000000.0
# 8560    b2f6a333  2020-01-03        1.0     1.0        1.0       104.0
# 125164  3367d334  2020-01-03        1.0     1.0        1.0       186.0
# 8561    b2f6a333  2020-01-04        1.0     1.0        1.0       180.0
# 92413   78833522  2020-01-04        1.0     0.0        1.0  90000000.0
# 125165  3367d334  2020-01-04        1.0     1.0        1.0       231.0
# 94066   f1559d46  2020-01-04        1.0     0.0        2.0         2.0
# ...

# %%
res1=df0.groupby(by=df['Date'],as_index=True,sort=True,group_keys=True)
print(res1)

# %%
m=list[5,6,8]
m
# Out:
# list[5, 6, 8]

# %%
d=df0['date'].groupby(df['Date'])

# %%
y1=df0['confirmed'].groupby(df['Date']).sum()
y2=df0['deaths'].groupby(df['Date']).sum()
y3=df0['recovered'].groupby(df['Date']).sum()

y2
# Out:
# Date
# 20200101          2.0
# 20200102          2.0
# 20200103          2.0
# 20200104          2.0
# 20200105          2.0
#               ...
# 20201227    1812375.0
# 20201228    1822264.0
# 20201229    1836635.0
# 20201230    1851461.0
# 20201231    1864643.0
# Name: deaths, Length: 366, dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.plot(y1.index,y1,color='blue',linewidth='2')
plt.plot(y1.index,y2,color='r',linewidth='2')
plt.plot(y1.index,y3,color='g',linewidth='2')
plt.xlabel("Days")
plt.ylabel("confirmed ,deaths ,recovered")
plt.xticks(rotation=90,label=list(df0['date'].groupby(df['Date']).sum()))
plt.show()

# %%
df0
# Out:
#               id        date  confirmed  deaths  recovered      tests  \
# 8558    b2f6a333  2020-01-01        1.0     1.0        1.0        4.0
# 125162  3367d334  2020-01-01        1.0     1.0        1.0       25.0
# 8559    b2f6a333  2020-01-02        1.0     1.0        1.0       99.0
# 125163  3367d334  2020-01-02        1.0     1.0        1.0       97.0
# 93250   42079406  2020-01-02        1.0     0.0        1.0   129291.0
# ...          ...         ...        ...     ...        ...        ...
# 155764  1b6bb022  2020-12-31   124630.0  2682.0   107069.0  1818260.0
# 152488  de4882cd  2020-12-31      122.0     2.0        1.0   853003.0
# 100166  c33e1ad7  2020-12-31    96458.0  1670.0    78737.0  1055691.0
# 128803  8bbab6df  2020-12-31   322514.0  9537.0   150102.0  2227027.0
# 53206   4b81000f  2020-12-31   143834.0   245.0   141422.0    10811.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated    hosp  ...  \
# ...

# %%
plt.figure(figsize=(25,30))
sns.lineplot(x=df0['Date'],y=df['confirmed'],hue=df0['administrative_area_level_1'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='confirmed'>

# %%
ll=list()

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
plt.plot(y1.index,y1,color='blue',linewidth='2')
plt.xticks(rotation=90)

plt.subplot(2,2,2)
plt.plot(y1.index,y2,color='r',linewidth='2')
plt.xticks(rotation=90)
plt.subplot(2,2,3)
plt.plot(y1.index,y3,color='g',linewidth='2')
plt.xticks(rotation=90)
plt.subplot(2,2,4)
plt.plot(y1.index,y1,color='blue',linewidth='2')
plt.plot(y1.index,y2,color='r',linewidth='2')
plt.plot(y1.index,y3,color='g',linewidth='2')
plt.show()

# %%
confirmed=list(df0.groupby(['Date']).agg(
        {"confirmed":["sum"]}))

deaths=df0.groupby(['Date']).agg(
        {"deaths":["sum"]})

recovered=df0.groupby(['Date']).agg(
        {"recovered":["sum"]})
recovered
# Out:
#            recovered
#                  sum
# Date
# 20200101         2.0
# 20200102         3.0
# 20200103         3.0
# 20200104         5.0
# 20200105         5.0
# ...              ...
# 20201227  45943524.0
# 20201228  45920520.0
# 20201229  46268095.0
# 20201230  46644031.0
# 20201231  46991445.0
#
# [366 rows x 1 columns]

# %% [markdown]
# --GOVENMENT MEASURES  of india

# %%
ind=df[df['administrative_area_level_1']=='India']
ind.sort_values(by='Date')
# Out:
#               id        date   confirmed    deaths  recovered        tests  \
# 124343  c39bfe6c  2020-01-22         1.0       1.0        3.0       6500.0
# 124344  c39bfe6c  2020-01-23         1.0       1.0        3.0       6500.0
# 124345  c39bfe6c  2020-01-24         1.0       1.0        3.0       6500.0
# 124346  c39bfe6c  2020-01-25         1.0       1.0        3.0       6500.0
# 124347  c39bfe6c  2020-01-26         1.0       1.0        3.0       6500.0
# ...          ...         ...         ...       ...        ...          ...
# 125157  c39bfe6c  2022-04-15  43040947.0  521747.0        1.0  831177370.0
# 125158  c39bfe6c  2022-04-16  43042097.0  521751.0        1.0  831478288.0
# 125159  c39bfe6c  2022-04-17  43044280.0  521965.0        1.0  831843406.0
# 125160  c39bfe6c  2022-04-18  43045527.0  521966.0        1.0         25.0
# 125161  c39bfe6c  2022-04-19  43047594.0  522006.0        1.0         25.0
#
# ...

# %%
ch=df[df['administrative_area_level_1']=='China']
ch.sort_values(by='Date')
# Out:
#              id        date  confirmed   deaths  recovered       tests  \
# 92412  78833522  2020-01-03        0.0      0.0        1.0  90000000.0
# 92413  78833522  2020-01-04        1.0      0.0        1.0  90000000.0
# 92414  78833522  2020-01-05        1.0      0.0        1.0  90000000.0
# 92415  78833522  2020-01-06        4.0      0.0        1.0  90000000.0
# 92416  78833522  2020-01-07        4.0      0.0        1.0  90000000.0
# ...         ...         ...        ...      ...        ...         ...
# 93245  78833522  2022-04-15   959392.0  14494.0        1.0    129291.0
# 93246  78833522  2022-04-16   965042.0  14561.0        1.0    129291.0
# 93247  78833522  2022-04-17   970368.0  14602.0        1.0    129291.0
# 93248  78833522  2022-04-18   974858.0  14634.0        1.0    129291.0
# 93249  78833522  2022-04-19   979966.0  14661.0        1.0    129291.0
#
#            vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# ...

# %%
ind=ind.sort_values(by='Date')
ind
# Out:
#               id        date   confirmed    deaths  recovered        tests  \
# 124343  c39bfe6c  2020-01-22         1.0       1.0        3.0       6500.0
# 124344  c39bfe6c  2020-01-23         1.0       1.0        3.0       6500.0
# 124345  c39bfe6c  2020-01-24         1.0       1.0        3.0       6500.0
# 124346  c39bfe6c  2020-01-25         1.0       1.0        3.0       6500.0
# 124347  c39bfe6c  2020-01-26         1.0       1.0        3.0       6500.0
# ...          ...         ...         ...       ...        ...          ...
# 125157  c39bfe6c  2022-04-15  43040947.0  521747.0        1.0  831177370.0
# 125158  c39bfe6c  2022-04-16  43042097.0  521751.0        1.0  831478288.0
# 125159  c39bfe6c  2022-04-17  43044280.0  521965.0        1.0  831843406.0
# 125160  c39bfe6c  2022-04-18  43045527.0  521966.0        1.0         25.0
# 125161  c39bfe6c  2022-04-19  43047594.0  522006.0        1.0         25.0
#
# ...

# %%
##dataframe other than india
other=df[df['administrative_area_level_1']!='India']
other=other.sort_values(by='Date')
other
# Out:
#               id        date  confirmed   deaths  recovered      tests  \
# 8558    b2f6a333  2020-01-01        1.0      1.0        1.0        4.0
# 125162  3367d334  2020-01-01        1.0      1.0        1.0       25.0
# 8559    b2f6a333  2020-01-02        1.0      1.0        1.0       99.0
# 125163  3367d334  2020-01-02        1.0      1.0        1.0       97.0
# 93250   42079406  2020-01-02        1.0      0.0        1.0   129291.0
# ...          ...         ...        ...      ...        ...        ...
# 71680   ef51ecaa  2022-04-19  3579877.0  13132.0        0.0        0.0
# 126820  bd23d325  2022-04-19  1653460.0  16794.0        3.0      166.0
# 95730   acb08e49  2022-04-20       19.0      1.0        1.0  7831696.0
# 98183   f54996f4  2022-04-20  7449548.0  29107.0        0.0        0.0
# 94903   f1559d46  2022-04-20  4084299.0  27263.0        1.0        0.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# ...

# %%
ind.head()
# Out:
#               id        date  confirmed  deaths  recovered   tests  vaccines  \
# 124343  c39bfe6c  2020-01-22        1.0     1.0        3.0  6500.0       0.0
# 124344  c39bfe6c  2020-01-23        1.0     1.0        3.0  6500.0       0.0
# 124345  c39bfe6c  2020-01-24        1.0     1.0        3.0  6500.0       0.0
# 124346  c39bfe6c  2020-01-25        1.0     1.0        3.0  6500.0       0.0
# 124347  c39bfe6c  2020-01-26        1.0     1.0        3.0  6500.0       0.0
#
#         people_vaccinated  people_fully_vaccinated  hosp  ...  \
# 124343                0.0                   7668.0   0.0  ...
# 124344                0.0                   7668.0   0.0  ...
# 124345                0.0                   7668.0   0.0  ...
# 124346                0.0                   7668.0   0.0  ...
# 124347                0.0                   7668.0   0.0  ...
#
#         containment_health_index  economic_support_index  \
# 124343                      0.00                     0.0
# ...

# %%
ddd=ind['date'].groupby(df['Date'])
ce=ind['cancel_events']
ce
ddd

# %%
l1=ind['school_closing'].groupby(df['Date']).sum()
l2=ind['workplace_closing'].groupby(df['Date']).sum()
l3=ind['cancel_events'].groupby(df['Date']).sum()
l4=ind['transport_closing'].groupby(df['Date']).sum()
l5=ind['stay_home_restrictions'].groupby(df['Date']).sum()
l6=ind['internal_movement_restrictions'].groupby(df['Date']).sum()
l7=ind['international_movement_restrictions'].groupby(df['Date']).sum()
l8=ind['information_campaigns'].groupby(df['Date']).sum()

l1.shape
# Out:
# (819,)

# %%
y1=ind['confirmed'].groupby(df['Date']).sum()
y2=ind['deaths'].groupby(df['Date']).sum()
y3=ind['recovered'].groupby(df['Date']).sum()

# %%
plt.figure(figsize=(15,9))
plt.subplot(3,3,1)
plt.plot(l1.index,l1,color="red")
plt.xlabel("Days")
plt.ylabel("school closing strightness")
plt.xticks(rotation=90)
plt.subplot(3,3,2)
plt.plot(l1.index,l2,color='g')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("Work place closing index")
plt.subplot(3,3,3)
plt.plot(l1.index,l3,color="blue")
plt.xlabel("Days")
plt.ylabel("confirmed ,deaths ,recovered")
plt.xticks(rotation=90)
plt.subplot(3,3,4)
plt.plot(l1.index,l1,color="red")
plt.xlabel("Days")
plt.ylabel("Transport closing index")
plt.xticks(rotation=90)
plt.subplot(3,3,5)
plt.plot(l1.index,l5,color='blue')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("stay at home index")
plt.subplot(3,3,6)
plt.plot(l1.index,l6,color="red")
plt.xlabel("Days")
plt.ylabel("Internal movement restrictions")
plt.xticks(rotation=90)
plt.subplot(3,3,7)
plt.plot(l1.index,l7,color="olive")
plt.xlabel("Days")
plt.ylabel("international_movement_restrictions")
plt.xticks(rotation=90)
plt.subplot(3,3,8)
plt.plot(l1.index,l8,color="orange")
plt.xlabel("Days")
plt.ylabel("information_campaigns")
plt.xticks(rotation=90)
plt.subplot(3,3,9)
plt.plot(y1.index,y1,color='blue',linewidth='2')
plt.plot(y1.index,y2,color='r',linewidth='2')
plt.plot(y1.index,y3,color='g',linewidth='2')
plt.xlabel("Days")
plt.ylabel("confirmed ,deaths ,recovered")
plt.xticks(rotation=90,label=list(df0['date'].groupby(df['Date']).sum()))
plt.show()

# %%
## indid vs us

# %%
usa=df[df['administrative_area_level_1']=='United States']
usa
usa=usa.sort_values(by='Date')
usa
# Out:
#               id        date   confirmed    deaths  recovered   tests  \
# 108831  59a13ceb  2020-01-21         1.0       0.0        2.0   348.0
# 108832  59a13ceb  2020-01-22         1.0       0.0        2.0   348.0
# 108833  59a13ceb  2020-01-23         1.0       0.0        2.0   348.0
# 108834  59a13ceb  2020-01-24         2.0       0.0        2.0   348.0
# 108835  59a13ceb  2020-01-25         3.0       0.0        2.0   348.0
# ...          ...         ...         ...       ...        ...     ...
# 109646  59a13ceb  2022-04-15  80512816.0  987171.0        2.0  3458.0
# 109647  59a13ceb  2022-04-16  80524337.0  987211.0        2.0  3458.0
# 109648  59a13ceb  2022-04-17  80534999.0  987228.0        2.0  3458.0
# 109649  59a13ceb  2022-04-18  80595074.0  987545.0        2.0  3458.0
# 109650  59a13ceb  2022-04-19  80645527.0  987999.0        2.0  3458.0
#
#            vaccines  people_vaccinated  people_fully_vaccinated     hosp  ...  \
# ...

# %%
ddd=usa['date'].groupby(df['Date'])
ce=usa['cancel_events']
ce
ddd

# %%
l1=usa['school_closing'].groupby(df['Date']).sum()
l2=usa['workplace_closing'].groupby(df['Date']).sum()
l3=usa['cancel_events'].groupby(df['Date']).sum()
l4=usa['transport_closing'].groupby(df['Date']).sum()
l5=usa['stay_home_restrictions'].groupby(df['Date']).sum()
l6=usa['internal_movement_restrictions'].groupby(df['Date']).sum()
l7=usa['international_movement_restrictions'].groupby(df['Date']).sum()
l8=usa['information_campaigns'].groupby(df['Date']).sum()

l1.shape
# Out:
# (820,)

# %%
y1=usa['confirmed'].groupby(df['Date']).sum()
y2=usa['deaths'].groupby(df['Date']).sum()
y3=usa['recovered'].groupby(df['Date']).sum()

# %%
plt.figure(figsize=(7,5))
plt.plot(l1.index,l1,color="red")
plt.xlabel("Days")
plt.ylabel("school closing strightness")
plt.xticks(rotation=90)
# Out:
# (array([20197500., 20200000., 20202500., 20205000., 20207500., 20210000.,
#         20212500., 20215000., 20217500., 20220000., 20222500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(18,10))
plt.subplot(3,3,1)
plt.plot(l1.index,l1,color="red")
plt.xlabel("Days")
plt.ylabel("school closing strightness")
plt.xticks(rotation=90)
plt.subplot(3,3,2)
plt.plot(l1.index,l2,color='g')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("Work place closing index")
plt.subplot(3,3,3)
plt.plot(l1.index,l3,color="blue")
plt.xlabel("Days")
plt.ylabel("cancel_events")
plt.xticks(rotation=90)
plt.subplot(3,3,4)
plt.plot(l1.index,l1,color="red")
plt.xlabel("Days")
plt.ylabel("Transport closing index")
plt.xticks(rotation=90)
plt.subplot(3,3,5)
plt.plot(l1.index,l5,color='blue')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("stay at home index")
plt.subplot(3,3,6)
plt.plot(l1.index,l6,color="red")
plt.xlabel("Days")
plt.ylabel("Internal movement restrictions")
plt.xticks(rotation=90)
plt.subplot(3,3,7)
plt.plot(l1.index,l7,color="olive")
plt.xlabel("Days")
plt.ylabel("international_movement_restrictions")
plt.xticks(rotation=90)
plt.subplot(3,3,8)
plt.plot(l1.index,l8,color="orange")
plt.xlabel("Days")
plt.ylabel("information_campaigns")
plt.xticks(rotation=90)
plt.subplot(3,3,9)
plt.plot(y1.index,y1,color='blue',linewidth='2')
plt.plot(y1.index,y2,color='r',linewidth='2')
plt.plot(y1.index,y3,color='g',linewidth='2')
plt.xlabel("Days")
plt.ylabel("confirmed ,deaths ,recovered")
plt.xticks(rotation=90,label=list(df0['date'].groupby(df['Date']).sum()))
plt.show()

# %%
ud1=usa['deaths'].groupby(df['Date']).sum()
id1=ind['deaths'].groupby(df['Date']).sum()
ud2=usa['recovered'].groupby(df['Date']).sum()
id2=ind['recovered'].groupby(df['Date']).sum()
ud3=usa['contact_tracing'].groupby(df['Date']).sum()
id3=ind['contact_tracing'].groupby(df['Date']).sum()
ud4=usa['people_vaccinated'].groupby(df['Date']).sum()
id4=ind['people_vaccinated'].groupby(df['Date']).sum()
ud5=usa['people_fully_vaccinated'].groupby(df['Date']).sum()
id5=ind['people_fully_vaccinated'].groupby(df['Date']).sum()

# %%
plt.figure(figsize=(20,14))
plt.subplot(3,2,1)
data=list([ud1,id1])
plt.boxplot(data)
plt.xlabel("us and india")
plt.ylabel("deaths")
plt.subplot(3,2,2)
data=list([ud2,id2])
plt.boxplot(data)
plt.xlabel("us and india")
plt.ylabel("recovered")
plt.subplot(3,2,3)
data=list([ud3,id3])
plt.boxplot(data)
plt.xlabel("us and india")
plt.ylabel("contact_tracing")
plt.subplot(3,2,4)
data=list([ud4,id4])
plt.boxplot(data)
plt.xlabel("us and india")
plt.ylabel("people_vaccinated")
plt.subplot(3,2,5)
data=list([ud5,id5])
plt.boxplot(data)
plt.xlabel("us and india")
plt.ylabel("people_fully_vaccinated")
plt.show()

# %% [markdown]
# --this shows that average death rate of usa is greater than death rate of india

# %% [markdown]
# ## health departments

# %%
ud1=usa['testing_policy'].groupby(df['Date']).sum()
id1=ind['testing_policy'].groupby(df['Date']).sum()
ud2=usa['vaccination_policy'].groupby(df['Date']).sum()
id2=ind['vaccination_policy'].groupby(df['Date']).sum()
ud3=usa['elderly_people_protection'].groupby(df['Date']).sum()
id3=ind['elderly_people_protection'].groupby(df['Date']).sum()
ud4=usa['government_response_index'].groupby(df['Date']).sum()
id4=ind['government_response_index'].groupby(df['Date']).sum()
ud5=usa['stringency_index'].groupby(df['Date']).sum()
id5=ind['stringency_index'].groupby(df['Date']).sum()
ud5=usa['facial_coverings'].groupby(df['Date']).sum()
id5=ind['facial_coverings'].groupby(df['Date']).sum()

# %% [markdown]
# ## economic aid

# %%
ud1=usa['economic_support_index'].groupby(df['Date']).sum() 
id1=ind['economic_support_index'].groupby(df['Date']).sum()

# %%
df=df.sort_values(by='Date')
df.head()
# Out:
#               id        date  confirmed  deaths  recovered     tests  \
# 8558    b2f6a333  2020-01-01        1.0     1.0        1.0       4.0
# 125162  3367d334  2020-01-01        1.0     1.0        1.0      25.0
# 8559    b2f6a333  2020-01-02        1.0     1.0        1.0      99.0
# 125163  3367d334  2020-01-02        1.0     1.0        1.0      97.0
# 93250   42079406  2020-01-02        1.0     0.0        1.0  129291.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# 8558     20491.0            20486.0                      5.0    0.0  ...
# 125162    2924.0             2924.0                   1958.0    0.0  ...
# 8559     20491.0            20486.0                      5.0    0.0  ...
# 125163    2924.0             2924.0                   1958.0    0.0  ...
# 93250    24376.0            24357.0                     19.0  263.0  ...
#
#         containment_health_index  economic_support_index  \
# ...

# %% [markdown]
# ## Effectiveness of vaccines

# %%
sns.barplot(x="year",y="people_fully_vaccinated",data=df)
plt.show()

# %% [markdown]
# ## 1)vaccination  policies

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
sns.barplot(x="year",y="people_fully_vaccinated",data=df,hue='vaccination_policy',ci=None)
plt.subplot(1,2,2)
sns.barplot(x="year",y="confirmed",data=df,hue='vaccination_policy',ci=None)
plt.show()

# %% [markdown]
# --let us consider the the vaccination trail of INDIA,CHINA and USA

# %%
#
plt.figure(figsize=(15,7))
sns.lineplot(x=ind['Date'],y=ind['people_fully_vaccinated'],color='orange')
sns.lineplot(x=ch['Date'],y=ch['people_fully_vaccinated'],color='red')
sns.lineplot(x=usa['Date'],y=usa['people_fully_vaccinated'],color='blue')
plt.plot()
# Out:
# []

# %%
# compare with above graph
plt.figure(figsize=(15,7))
sns.lineplot(x=ind['Date'],y=ind['deaths'],color='orange')
sns.lineplot(x=ch['Date'],y=ch['deaths'],color='red')
sns.lineplot(x=usa['Date'],y=usa['deaths'],color='blue')
plt.plot()
# Out:
# []

# %%
#  effectiveness of vaccine on deathrate in india 
sns.boxplot(x='vaccination_policy',y='deaths',data=ind)
# Out:
# <AxesSubplot:xlabel='vaccination_policy', ylabel='deaths'>

# %%
# no of people vaccinated during various vaccination policy
sns.boxplot(x='vaccination_policy',y='people_fully_vaccinated',data=ind)
# Out:
# <AxesSubplot:xlabel='vaccination_policy', ylabel='people_fully_vaccinated'>

# %% [markdown]
# ##  Effectiveness of mask on confirmed cases

# %%
ys=ind['confirmed'].groupby(df['facial_coverings']).sum()
yc=ind['confirmed'].groupby(df['facial_coverings']).count()
y=ys/yc
x=y.index
plt.bar(x,y,color=list(['red','orange','olive','blue','orange']))
plt.xlabel("facial_coverings")
plt.ylabel("confirmed")
# Out:
# Text(0, 0.5, 'confirmed')

# %%
plt.figure(figsize=(12,7))
plt.subplot(1,2,1)
sns.barplot(x="year",y="confirmed",data=ind,hue='facial_coverings',palette='Blues_d',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='facial_coverings')
plt.show()

# %%
sns.scatterplot(x=df['facial_coverings'],y=df['confirmed'],hue=df['administrative_area_level_1'])
# Out:
# <AxesSubplot:xlabel='facial_coverings', ylabel='confirmed'>

# %% [markdown]
# ##  effectiveness of lockdown(trensport_closing ,stay_home_restrictions,internal and international movement,)

# %%
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
sns.barplot(x="transport_closing",y="confirmed",data=ind,palette='Blues_d')

plt.subplot(2,2,2)
sns.barplot(x="stay_home_restrictions",y="confirmed",data=ind,palette='rocket')

plt.subplot(2,2,3)
sns.barplot(x="internal_movement_restrictions",y="confirmed",data=ind,palette='rocket')

plt.subplot(2,2,4)
sns.barplot(x="international_movement_restrictions",y="confirmed",data=ind,palette='Blues_d')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
ys=ind['confirmed'].groupby(df['transport_closing']).sum()
yc=ind['confirmed'].groupby(df['transport_closing']).count()
y=ys/yc
x=y.index
plt.bar(x,y,color=list(['red','orange','green']))
plt.xlabel("transport_closing")
plt.ylabel("confirmed")
plt.subplot(2,2,2)
ys=ind['confirmed'].groupby(df['stay_home_restrictions']).sum()
yc=ind['confirmed'].groupby(df['stay_home_restrictions']).count()
y=ys/yc
x=y.index
plt.bar(x,y,color=list(['red','orange','green']))
plt.xlabel("stay_home_restrictions")
plt.ylabel("confirmed")
plt.subplot(2,2,3)
ys=ind['confirmed'].groupby(df['internal_movement_restrictions']).sum()
yc=ind['confirmed'].groupby(df['internal_movement_restrictions']).count()
y=ys/yc
x=y.index
plt.bar(x,y,color=list(['red','orange','green']))
plt.xlabel("internal_movement_restrictions")
plt.ylabel("confirmed")
plt.subplot(2,2,4)
ys=ind['confirmed'].groupby(df['international_movement_restrictions']).sum()
yc=ind['confirmed'].groupby(df['international_movement_restrictions']).count()
y=ys/yc
x=y.index
plt.bar(x,y,color=list(['red','orange','green']))
plt.xlabel("international_movement_restrictions")
plt.ylabel("confirmed")
# Out:
# Text(0, 0.5, 'confirmed')

# %%
df.head()
# Out:
#               id        date  confirmed  deaths  recovered     tests  \
# 8558    b2f6a333  2020-01-01        1.0     1.0        1.0       4.0
# 125162  3367d334  2020-01-01        1.0     1.0        1.0      25.0
# 8559    b2f6a333  2020-01-02        1.0     1.0        1.0      99.0
# 125163  3367d334  2020-01-02        1.0     1.0        1.0      97.0
# 93250   42079406  2020-01-02        1.0     0.0        1.0  129291.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# 8558     20491.0            20486.0                      5.0    0.0  ...
# 125162    2924.0             2924.0                   1958.0    0.0  ...
# 8559     20491.0            20486.0                      5.0    0.0  ...
# 125163    2924.0             2924.0                   1958.0    0.0  ...
# 93250    24376.0            24357.0                     19.0  263.0  ...
#
#         containment_health_index  economic_support_index  \
# ...

# %%
c=df['population'].groupby(df['administrative_area_level_1']).sum()
l=c.index
cc=df['population'].groupby(df['administrative_area_level_1']).count()
cc
cd=c/cc
cd
ddf={
     "country":cd.index,
    "population":cd
   
}
ddf=pd.DataFrame(ddf)
ddf=ddf.sort_values(by='population',ascending=False)
ddf.head(15)
# Out:
#                                    country    population
# administrative_area_level_1
# China                                China  1.392730e+09
# India                                India  1.352617e+09
# United States                United States  3.266875e+08
# Indonesia                        Indonesia  2.676634e+08
# Pakistan                          Pakistan  2.122150e+08
# Brazil                              Brazil  2.094693e+08
# Nigeria                            Nigeria  1.958747e+08
# Bangladesh                      Bangladesh  1.613560e+08
# Russia                              Russia  1.444780e+08
# Japan                                Japan  1.265291e+08
# Mexico                              Mexico  1.261908e+08
# Ethiopia                          Ethiopia  1.092246e+08
# Philippines                    Philippines  1.066519e+08
# Egypt                                Egypt  9.842360e+07
# Vietnam                            Vietnam  9.554040e+07

# %%
## top 10 countries with hifhest population
ddf=ddf.iloc[0:11,0:2]

# %%
b=df['confirmed'].groupby(df['administrative_area_level_1']).sum()
m=b.index
bb=df['confirmed'].groupby(df['administrative_area_level_1']).count()
bb
bd=b/bb
cd
bbf={
     "country":bd.index,
    "confirmed":bd
   
}
bbf=pd.DataFrame(bbf)
bbf=bbf.sort_values(by='confirmed',ascending=False)
bbf.head(15)
# Out:
#                                     country     confirmed
# administrative_area_level_1
# United States                 United States  2.824267e+07
# India                                 India  1.808372e+07
# Brazil                               Brazil  1.284445e+07
# United Kingdom               United Kingdom  5.569176e+06
# France                               France  5.497878e+06
# Russia                               Russia  5.001266e+06
# Turkey                               Turkey  4.335003e+06
# Germany                             Germany  3.817251e+06
# Italy                                 Italy  3.768291e+06
# Spain                                 Spain  3.405791e+06
# Argentina                         Argentina  2.965341e+06
# Iran                                   Iran  2.678365e+06
# Colombia                           Colombia  2.259503e+06
# Mexico                               Mexico  2.076201e+06
# Poland                               Poland  1.989138e+06

# %%
## top 10 countries with hifhest population
bbf=bbf.iloc[0:11,0:2]

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
x=ddf['country']
y=ddf['population']
plt.title('POPULATION')
plt.pie(y,labels=x,autopct='%0.1f%%',colors=['cyan','orange','red','cyan','green','yellow','blue','white','magenta'])
plt.subplot(1,2,2)
x=bbf['country']
y=bbf['confirmed']
plt.title('CONFIRMED CASES')
plt.pie(y,labels=x,autopct='%0.1f%%',colors=['cyan','orange','red','cyan','green','yellow','blue','white','magenta'])
plt.show()

# %%
ind.head()
# Out:
#               id        date  confirmed  deaths  recovered   tests  vaccines  \
# 124343  c39bfe6c  2020-01-22        1.0     1.0        3.0  6500.0       0.0
# 124344  c39bfe6c  2020-01-23        1.0     1.0        3.0  6500.0       0.0
# 124345  c39bfe6c  2020-01-24        1.0     1.0        3.0  6500.0       0.0
# 124346  c39bfe6c  2020-01-25        1.0     1.0        3.0  6500.0       0.0
# 124347  c39bfe6c  2020-01-26        1.0     1.0        3.0  6500.0       0.0
#
#         people_vaccinated  people_fully_vaccinated  hosp  ...  \
# 124343                0.0                   7668.0   0.0  ...
# 124344                0.0                   7668.0   0.0  ...
# 124345                0.0                   7668.0   0.0  ...
# 124346                0.0                   7668.0   0.0  ...
# 124347                0.0                   7668.0   0.0  ...
#
#         containment_health_index  economic_support_index  \
# 124343                      0.00                     0.0
# ...

# %%
l1=ind['school_closing'].groupby(df['Date']).sum()
l2=ind['workplace_closing'].groupby(df['Date']).sum()
l3=ind['cancel_events'].groupby(df['Date']).sum()
l4=ind['transport_closing'].groupby(df['Date']).sum()
l5=ind['stay_home_restrictions'].groupby(df['Date']).sum()
l6=ind['internal_movement_restrictions'].groupby(df['Date']).sum()
l7=ind['international_movement_restrictions'].groupby(df['Date']).sum()
l8=ind['information_campaigns'].groupby(df['Date']).sum()

l1.shape
# Out:
# (819,)

# %%
c1=ch['school_closing'].groupby(df['Date']).sum()
c2=ch['workplace_closing'].groupby(df['Date']).sum()
c3=ch['cancel_events'].groupby(df['Date']).sum()
c4=ch['transport_closing'].groupby(df['Date']).sum()
c5=ch['stay_home_restrictions'].groupby(df['Date']).sum()
c6=ch['internal_movement_restrictions'].groupby(df['Date']).sum()
c7=ch['international_movement_restrictions'].groupby(df['Date']).sum()
c8=ch['information_campaigns'].groupby(df['Date']).sum()

# %%
u1=usa['school_closing'].groupby(df['Date']).sum()
u2=usa['workplace_closing'].groupby(df['Date']).sum()
u3=usa['cancel_events'].groupby(df['Date']).sum()
u4=usa['transport_closing'].groupby(df['Date']).sum()
u5=usa['stay_home_restrictions'].groupby(df['Date']).sum()
u6=usa['internal_movement_restrictions'].groupby(df['Date']).sum()
u7=usa['international_movement_restrictions'].groupby(df['Date']).sum()
u8=usa['information_campaigns'].groupby(df['Date']).sum()

u1.shape
# Out:
# (820,)

# %%
plt.figure(figsize=(23,40))
plt.subplot(8,3,1)
plt.plot(c1.index,c1,color="red")
plt.xlabel("Days")
plt.ylabel("school closing strightness")
plt.xticks(rotation=90)

plt.subplot(8,3,2)
plt.plot(l1.index,l1,color="blue")
plt.xlabel("Days")
plt.ylabel("school closing strightness")
plt.xticks(rotation=90)

plt.subplot(8,3,3)
plt.plot(u1.index,u1,color="olive")
plt.xlabel("Days")
plt.ylabel("school closing strightness")
plt.xticks(rotation=90)

plt.subplot(8,3,4)
plt.plot(c1.index,c2,color='red')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("Work place closing index")

plt.subplot(8,3,5)
plt.plot(l1.index,l2,color='blue')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("Work place closing index")

plt.subplot(8,3,6)
plt.plot(u1.index,u2,color='olive')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("Work place closing index")

plt.subplot(8,3,7)
plt.plot(c1.index,c3,color="red")
plt.xlabel("Days")
plt.ylabel("cancel_events")
plt.xticks(rotation=90)

plt.subplot(8,3,8)
plt.plot(l1.index,l3,color="blue")
plt.xlabel("Days")
plt.ylabel("cancel_events")
plt.xticks(rotation=90)

plt.subplot(8,3,9)
plt.plot(u1.index,u3,color="olive")
plt.xlabel("Days")
plt.ylabel("cancel_events")
plt.xticks(rotation=90)

plt.subplot(8,3,10)
plt.plot(c1.index,c4,color="red")
plt.xlabel("Days")
plt.ylabel("Transport closing index")
plt.xticks(rotation=90)

plt.subplot(8,3,11)
plt.plot(l1.index,l4,color="blue")
plt.xlabel("Days")
plt.ylabel("Transport closing index")
plt.xticks(rotation=90)

plt.subplot(8,3,12)
plt.plot(u1.index,u4,color="olive")
plt.xlabel("Days")
plt.ylabel("Transport closing index")
plt.xticks(rotation=90)


plt.subplot(8,3,13)
plt.plot(c1.index,c5,color='red')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("stay at home index")

plt.subplot(8,3,14)
plt.plot(l1.index,l5,color='blue')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("stay at home index")

plt.subplot(8,3,15)
plt.plot(u1.index,u5,color='olive')
plt.xticks(rotation=90)
plt.xlabel("Days")
plt.ylabel("stay at home index")


plt.subplot(8,3,16)
plt.plot(c1.index,c6,color="red")
plt.xlabel("Days")
plt.ylabel("Internal movement restrictions")
plt.xticks(rotation=90)

plt.subplot(8,3,17)
plt.plot(l1.index,l6,color="blue")
plt.xlabel("Days")
plt.ylabel("Internal movement restrictions")
plt.xticks(rotation=90)

plt.subplot(8,3,18)
plt.plot(u1.index,u6,color="olive")
plt.xlabel("Days")
plt.ylabel("Internal movement restrictions")
plt.xticks(rotation=90)

plt.subplot(8,3,19)
plt.plot(c1.index,c7,color="red")
plt.xlabel("Days")
plt.ylabel("international_movement_restrictions")
plt.xticks(rotation=90)

plt.subplot(8,3,20)
plt.plot(l1.index,l7,color="blue")
plt.xlabel("Days")
plt.ylabel("international_movement_restrictions")
plt.xticks(rotation=90)

plt.subplot(8,3,21)
plt.plot(u1.index,u7,color="olive")
plt.xlabel("Days")
plt.ylabel("international_movement_restrictions")
plt.xticks(rotation=90)

plt.subplot(8,3,22)
plt.plot(c1.index,c8,color="red")
plt.xlabel("Days")
plt.ylabel("information_campaigns")
plt.xticks(rotation=90)

plt.subplot(8,3,23)
plt.plot(l1.index,l8,color="blue")
plt.xlabel("Days")
plt.ylabel("information_campaigns")
plt.xticks(rotation=90)

plt.subplot(8,3,24)
plt.plot(u1.index,u8,color="olive")
plt.xlabel("Days")
plt.ylabel("information_campaigns")
plt.xticks(rotation=90)

plt.show()

# %%
df0=df[df['year']==2020]
df1=df[df['year']==2021]
df2=df[df['year']==2022]

# %%
ind['school_closing'].head(100)
# Out:
# 124343    0.0
# 124344    0.0
# 124345    0.0
# 124346    0.0
# 124347    0.0
#          ...
# 124438    3.0
# 124439    3.0
# 124440    3.0
# 124441    3.0
# 124442    3.0
# Name: school_closing, Length: 100, dtype: float64

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='school_closing',palette='Blues_d',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='school_closing')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='workplace_closing',palette='rocket',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='workplace_closing')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='cancel_events',palette='rocket',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='cancel_events')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='transport_closing',palette='Blues_d',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='transport_closing')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='stay_home_restrictions',palette='rocket',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='stay_home_restrictions')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='internal_movement_restrictions',palette='vlag',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='internal_movement_restrictions')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='confirmed',data=ind,hue='information_campaigns',palette='rocket',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='information_campaigns')
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
sns.barplot(x='year',y='information_campaigns',data=ind,hue='information_campaigns',palette='rocket',ci=None)
plt.subplot(1,2,2)
sns.countplot(x="year", data=ind,hue='information_campaigns')
plt.show()

# %%
l1=ind['people_fully_vaccinated'].groupby(df['Date']).sum()
sns.countplot
# Out:
# <function seaborn.categorical.countplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, dodge=True, ax=None, **kwargs)>

# %%
df
# Out:
#               id        date  confirmed   deaths  recovered      tests  \
# 8558    b2f6a333  2020-01-01        1.0      1.0        1.0        4.0
# 125162  3367d334  2020-01-01        1.0      1.0        1.0       25.0
# 8559    b2f6a333  2020-01-02        1.0      1.0        1.0       99.0
# 125163  3367d334  2020-01-02        1.0      1.0        1.0       97.0
# 93250   42079406  2020-01-02        1.0      0.0        1.0   129291.0
# ...          ...         ...        ...      ...        ...        ...
# 166066  777d6f0a  2022-04-19    20865.0    383.0       33.0   605573.0
# 87657   5aac4bc4  2022-04-19        1.0    758.0      903.0       42.0
# 95730   acb08e49  2022-04-20       19.0      1.0        1.0  7831696.0
# 98183   f54996f4  2022-04-20  7449548.0  29107.0        0.0        0.0
# 94903   f1559d46  2022-04-20  4084299.0  27263.0        1.0        0.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# ...

# %%
## of india country
plt.figure(figsize=(15,8))
sns.scatterplot(x=ind['facial_coverings'],y=ind['confirmed'],hue=ind['year'])
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x=ind['Date'],y=ind['confirmed'],color='orange')
sns.lineplot(x=ch['Date'],y=ch['confirmed'],color='red')
sns.lineplot(x=usa['Date'],y=usa['confirmed'],color='blue')
plt.legend(['INDIA','china','USA'])
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x=ind['Date'],y=ind['people_fully_vaccinated'],color='orange')
sns.lineplot(x=ch['Date'],y=ch['people_fully_vaccinated'],color='red')
sns.lineplot(x=usa['Date'],y=usa['people_fully_vaccinated'],color='blue')
plt.legend(['INDIA','chaina','USA'])

plt.plot()
# Out:
# []

# %%
df
# Out:
#               id        date  confirmed   deaths  recovered      tests  \
# 8558    b2f6a333  2020-01-01        1.0      1.0        1.0        4.0
# 125162  3367d334  2020-01-01        1.0      1.0        1.0       25.0
# 8559    b2f6a333  2020-01-02        1.0      1.0        1.0       99.0
# 125163  3367d334  2020-01-02        1.0      1.0        1.0       97.0
# 93250   42079406  2020-01-02        1.0      0.0        1.0   129291.0
# ...          ...         ...        ...      ...        ...        ...
# 166066  777d6f0a  2022-04-19    20865.0    383.0       33.0   605573.0
# 87657   5aac4bc4  2022-04-19        1.0    758.0      903.0       42.0
# 95730   acb08e49  2022-04-20       19.0      1.0        1.0  7831696.0
# 98183   f54996f4  2022-04-20  7449548.0  29107.0        0.0        0.0
# 94903   f1559d46  2022-04-20  4084299.0  27263.0        1.0        0.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.distplot(df['deaths'])
# Out:
# C:\Users\mange\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='deaths', ylabel='Density'>

# %%
sns.jointplot(x='Date',y='confirmed',data=ind,kind="reg")
plt.plot()
# Out:
# []

# %%
## confirmed cases based on testing policy
sns.boxplot(x='year',y='confirmed',hue='testing_policy',data=ind)
plt.title("INDIA")
plt.show()

# %%
## confirmed cases based on testing policy
sns.boxplot(x='year',y='tests',hue='testing_policy',data=ind)
plt.title("INDIA")
plt.show()

# %%
## confirmed cases based on testing policy
sns.boxplot(x='year',y='confirmed',hue='testing_policy',data=usa)
plt.title("USA")
plt.show()

# %%
## confirmed cases based on testing policy
sns.boxplot(x='year',y='tests',hue='testing_policy',data=usa)
plt.title("USA")
plt.show()

# %%
## confirmed cases based on testing policy
sns.boxplot(x='year',y='confirmed',hue='testing_policy',data=ch)
plt.title("CHINA")
plt.show()

# %%
## confirmed cases based on testing policy
sns.boxplot(x='year',y='tests',hue='testing_policy',data=ch)
plt.title("CHINA")
plt.show()

# %%
## confirmed cases based on testing policy

plt.figure(figsize=(20,12))
sns.boxplot(x='year',y='confirmed',hue='testing_policy',data=df)
plt.title("CHINA")
plt.show()

# %%
df.head
# Out:
# <bound method NDFrame.head of               id        date  confirmed   deaths  recovered      tests  \
# 8558    b2f6a333  2020-01-01        1.0      1.0        1.0        4.0
# 125162  3367d334  2020-01-01        1.0      1.0        1.0       25.0
# 8559    b2f6a333  2020-01-02        1.0      1.0        1.0       99.0
# 125163  3367d334  2020-01-02        1.0      1.0        1.0       97.0
# 93250   42079406  2020-01-02        1.0      0.0        1.0   129291.0
# ...          ...         ...        ...      ...        ...        ...
# 166066  777d6f0a  2022-04-19    20865.0    383.0       33.0   605573.0
# 87657   5aac4bc4  2022-04-19        1.0    758.0      903.0       42.0
# 95730   acb08e49  2022-04-20       19.0      1.0        1.0  7831696.0
# 98183   f54996f4  2022-04-20  7449548.0  29107.0        0.0        0.0
# 94903   f1559d46  2022-04-20  4084299.0  27263.0        1.0        0.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# ...

# %%
sns.barplot(x='year',y='people_fully_vaccinated',data=df)
plt.show()

# %%
#plt.figure(figsize=(15,7))
#l=df['year']
#y=df['people_fully_vaccinated']
#y1=df['confirmed']
#plt.bar( l-0.2, y, 0.4,label='people_fully_vaccinated')
#plt.bar(l+0.2, y1, 0.4, label = 'confirmed')
  
#plt.show()

# %%
df
# Out:
#               id        date  confirmed   deaths  recovered      tests  \
# 8558    b2f6a333  2020-01-01        1.0      1.0        1.0        4.0
# 125162  3367d334  2020-01-01        1.0      1.0        1.0       25.0
# 8559    b2f6a333  2020-01-02        1.0      1.0        1.0       99.0
# 125163  3367d334  2020-01-02        1.0      1.0        1.0       97.0
# 93250   42079406  2020-01-02        1.0      0.0        1.0   129291.0
# ...          ...         ...        ...      ...        ...        ...
# 166066  777d6f0a  2022-04-19    20865.0    383.0       33.0   605573.0
# 87657   5aac4bc4  2022-04-19        1.0    758.0      903.0       42.0
# 95730   acb08e49  2022-04-20       19.0      1.0        1.0  7831696.0
# 98183   f54996f4  2022-04-20  7449548.0  29107.0        0.0        0.0
# 94903   f1559d46  2022-04-20  4084299.0  27263.0        1.0        0.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated   hosp  ...  \
# ...

# %%
c1=df.groupby(['administrative_area_level_1','year']).sum()
c1.sort_values(by='population',ascending=False)
# Out:
#                                      confirmed       deaths     recovered  \
# administrative_area_level_1 year
# China                       2021  4.184101e+07    1933041.0  3.650000e+02
#                             2020  2.855497e+07    1415929.0  3.640000e+02
# India                       2021  9.215076e+09  121382644.0  3.908329e+09
#                             2020  1.084280e+09   17171647.0  9.511725e+08
# China                       2022  4.965137e+07     913939.0  1.090000e+02
# ...                                        ...          ...           ...
# Niue                        2022  7.200000e+01         72.0  0.000000e+00
# Holy See                    2022  3.098000e+03        108.0  2.160000e+02
# Costa Atlantica             2020  1.163800e+04          0.0  7.291000e+03
# Grand Princess              2020  6.700000e+01          0.0  0.000000e+00
# Pitcairn                    2021  8.500000e+01         85.0  8.500000e+01
#
# ...

# %%
c1.index
# Out:
# MultiIndex([(      'Afghanistan', 2020),
#             (      'Afghanistan', 2021),
#             (      'Afghanistan', 2022),
#             (          'Albania', 2020),
#             (          'Albania', 2021),
#             (          'Albania', 2022),
#             (          'Algeria', 2020),
#             (          'Algeria', 2021),
#             (          'Algeria', 2022),
#             (   'American Samoa', 2021),
#             ...
#             ('Wallis and Futuna', 2022),
#             (            'Yemen', 2020),
#             (            'Yemen', 2021),
#             (            'Yemen', 2022),
#             (           'Zambia', 2020),
#             (           'Zambia', 2021),
#             (           'Zambia', 2022),
#             (         'Zimbabwe', 2020),
#             (         'Zimbabwe', 2021),
#             (         'Zimbabwe', 2022)],
#            names=['administrative_area_level_1', 'year'], length=689)

# %%
c2=df.groupby(['administrative_area_level_1','year']).count()
c2
# Out:
#                                    id  date  confirmed  deaths  recovered  \
# administrative_area_level_1 year
# Afghanistan                 2020  345   345        345     345        345
#                             2021  365   365        365     365        365
#                             2022  109   109        109     109        109
# Albania                     2020  345   345        345     345        345
#                             2021  365   365        365     365        365
# ...                               ...   ...        ...     ...        ...
# Zambia                      2021  365   365        365     365        365
#                             2022  109   109        109     109        109
# Zimbabwe                    2020  345   345        345     345        345
#                             2021  365   365        365     365        365
#                             2022  109   109        109     109        109
#
# ...

# %%
c3=c1/c2

# %%
c3=c3.sort_values(by='population',ascending=False)

# %%
c3=c3[0:30]
c3.head(30)
# Out:
#                                           Date  administrative_area_level  \
# administrative_area_level_1 year
# China                       2021  2.021067e+07                        1.0
#                             2020  2.020067e+07                        1.0
#                             2022  2.022025e+07                        1.0
# India                       2020  2.020070e+07                        1.0
#                             2021  2.021067e+07                        1.0
#                             2022  2.022025e+07                        1.0
# United States               2020  2.020070e+07                        1.0
#                             2022  2.022025e+07                        1.0
#                             2021  2.021067e+07                        1.0
# Indonesia                   2020  2.020070e+07                        1.0
#                             2021  2.021067e+07                        1.0
# ...

# %%
c3 = pd.DataFrame(c3)
c3
# Out:
#                                           Date  administrative_area_level  \
# administrative_area_level_1 year
# China                       2021  2.021067e+07                        1.0
#                             2020  2.020067e+07                        1.0
#                             2022  2.022025e+07                        1.0
# India                       2020  2.020070e+07                        1.0
#                             2021  2.021067e+07                        1.0
#                             2022  2.022025e+07                        1.0
# United States               2020  2.020070e+07                        1.0
#                             2022  2.022025e+07                        1.0
#                             2021  2.021067e+07                        1.0
# Indonesia                   2020  2.020070e+07                        1.0
#                             2021  2.021067e+07                        1.0
# ...

# %%
c4=df.groupby(['administrative_area_level_1']).sum()
c5=df.groupby(['administrative_area_level_1']).count()
c6=c4/c5;
c6=c6.sort_values(by='population',ascending=False)
c6=c6.reset_index(level=['administrative_area_level_1'])
c6=c6[0:10]
c6.head(10)
# Out:
#   administrative_area_level_1          Date  administrative_area_level  \
# 0                       China  2.020757e+07                        1.0
# 1                       India  2.020774e+07                        1.0
# 2               United States  2.020774e+07                        1.0
# 3                   Indonesia  2.020773e+07                        1.0
# 4                    Pakistan  2.020773e+07                        1.0
# 5                      Brazil  2.020807e+07                        1.0
# 6                     Nigeria  2.020774e+07                        1.0
# 7                  Bangladesh  2.020773e+07                        1.0
# 8                      Russia  2.020773e+07                        1.0
# 9                       Japan  2.020776e+07                        1.0
#
#    cancel_events     confirmed  contact_tracing  containment_health_index  \
# 0       1.908115  1.432546e+05         1.976134                 70.092279
# ...

# %%
y1=c6['population']
y2=c6['confirmed']
X_axis = np.arange(len(c6))
plt.bar(X_axis - 0.5, y1, 0.2, label = 'population')
plt.bar(X_axis + 0.1, y2, 0.2, label = 'confirmed')
plt.bar(X_axis + 0.2, y1, 0.2, label = 'population')
# Out:
# <BarContainer object of 10 artists>

# %%
y1=list[c6['facial_coverings'],c6['school_closing']]
y1
# Out:
# list[0    2.372315
# 1    3.369963
# 2    2.991463
# 3    3.386308
# 4    2.910758
# 5    3.512102
# 6    2.683761
# 7    3.255501
# 8    2.138142
# 9    0.968293
# Name: facial_coverings, dtype: float64, 0    2.491647
# 1    2.371184
# 2    2.254878
# 3    2.165037
# 4    2.130807
# 5    2.433121
# 6    1.158730
# 7    2.392421
# 8    1.430318
# 9    1.225610
# Name: school_closing, dtype: float64]

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=c6, x=y1, hue="year")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10588/3341376192.py in <module>
#       1 plt.figure(figsize=(15,7))
# ----> 2 sns.histplot(data=c6, x=y1, hue="year")
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1428 ):
#    1429
# -> 1430     p = _DistributionPlotter(
#    1431         data=data,
#    1432         variables=_DistributionPlotter.get_semantics(locals())
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in __init__(self, data, variables)
#     109     ):
#     110
# ...

# %%
c7=df.groupby(['year']).sum()
c8=df.groupby(['year']).count()
c9=c7/c8
#c9=c9.sort_values(by='population',ascending=False)
c9=c9.reset_index(level=['year'])
c9
# Out:
#    year          Date  administrative_area_level  administrative_area_level_1  \
# 0  2020  2.020071e+07                        1.0                          NaN
# 1  2021  2.021067e+07                        1.0                          NaN
# 2  2022  2.022025e+07                        1.0                          NaN
#
#    cancel_events     confirmed  contact_tracing  containment_health_index  \
# 0       1.142401  9.978342e+04         1.121493                 40.957450
# 1       1.145781  8.037939e+05         1.156836                 46.443300
# 2       0.924363  1.818734e+06         0.942680                 39.520626
#
#    date        deaths  ...  school_closing  stay_home_restrictions  \
# 0   NaN   3163.395764  ...        1.540834                0.830558
# 1   NaN  16790.749940  ...        1.126567                0.870609
# 2   NaN  24688.981193  ...        0.749213                0.471278
#
#    stringency_index  testing_policy         tests  transport_closing  \
# ...

# %%
plt.figure(figsize=(15,7))
y1=c9['school_closing']
y2=c9['workplace_closing']
y3=c9['cancel_events']
y4=c9['gatherings_restrictions']
y5=c9['transport_closing']
y6=c9['stay_home_restrictions']
X_axis = np.arange(len(c9))
plt.bar(X_axis - 0.1, y1, 0.1, label = 'school_closing')
plt.bar(X_axis - 0.2, y2, 0.1, label = 'workplace_closing')
plt.bar(X_axis - 0.3, y3, 0.1, label = 'cancel_events')
plt.bar(X_axis - 0.4, y4, 0.1, label = 'gatherings_restrictions')
plt.bar(X_axis + 0.0, y5, 0.1, label = 'transport_closing')
plt.bar(X_axis + 0.1, y6, 0.1, label = 'stay_home_restrictions')
#plt.xlabel("Days")
#plt.ylabel("school closing strightness")
plt.xticks(label=c9['year'],rotation=90)
plt.legend()
plt.show()

# %%
ch=ch.reset_index()
ind=ind.reset_index()

usa=usa.reset_index()

# %%
usa
# Out:
#       index        id        date   confirmed    deaths  recovered   tests  \
# 0    108831  59a13ceb  2020-01-21         1.0       0.0        2.0   348.0
# 1    108832  59a13ceb  2020-01-22         1.0       0.0        2.0   348.0
# 2    108833  59a13ceb  2020-01-23         1.0       0.0        2.0   348.0
# 3    108834  59a13ceb  2020-01-24         2.0       0.0        2.0   348.0
# 4    108835  59a13ceb  2020-01-25         3.0       0.0        2.0   348.0
# ..      ...       ...         ...         ...       ...        ...     ...
# 815  109646  59a13ceb  2022-04-15  80512816.0  987171.0        2.0  3458.0
# 816  109647  59a13ceb  2022-04-16  80524337.0  987211.0        2.0  3458.0
# 817  109648  59a13ceb  2022-04-17  80534999.0  987228.0        2.0  3458.0
# 818  109649  59a13ceb  2022-04-18  80595074.0  987545.0        2.0  3458.0
# 819  109650  59a13ceb  2022-04-19  80645527.0  987999.0        2.0  3458.0
#
#         vaccines  people_vaccinated  people_fully_vaccinated  ...  \
# ...

# %%
ch['con']=ch['confirmed']
ch['rec']=ch['recovered']
ch['det']=ch['deaths']
ch['vac']=ch['people_fully_vaccinated']
for i in range (837,0,-1):
        ch["con"][i]=ch['confirmed'][i]-ch['confirmed'][i-1]
        ch["rec"][i]=ch['recovered'][i]-ch['recovered'][i-1]
        ch["det"][i]=ch['deaths'][i]-ch['deaths'][i-1]
        ch["det"][i]=ch['people_fully_vaccinated'][i]-ch['people_fully_vaccinated'][i-1]
    
ch.head(500)
    #calculating freq
    
ind['con']=ind['confirmed']
ind['rec']=ind['recovered']
ind['det']=ind['deaths']
ind['vac']=ind['people_fully_vaccinated']
for i in range (818,0,-1):
        ind["con"][i]=ind['confirmed'][i]-ind['confirmed'][i-1]
        ind["rec"][i]=ind['recovered'][i]-ind['recovered'][i-1]
        ind["det"][i]=ind['deaths'][i]-ind['deaths'][i-1]
        ind["det"][i]=ind['people_fully_vaccinated'][i]-ind['people_fully_vaccinated'][i-1]
    
ind.head(500)
    #calculating freq
    
    
usa['con']=usa['confirmed']
usa['rec']=usa['recovered']
usa['det']=usa['deaths']
usa['vac']=usa['deaths']
for i in range (819,0,-1):
        usa["con"][i]=usa['confirmed'][i]-usa['confirmed'][i-1]
        usa["rec"][i]=usa['recovered'][i]-usa['recovered'][i-1]
        usa["det"][i]=usa['deaths'][i]-usa['deaths'][i-1]
        usa["det"][i]=usa['people_fully_vaccinated'][i]-usa['people_fully_vaccinated'][i-1]
    
ch.head(500)
    #calculating freq
# Out:
# C:\Users\mange\AppData\Local\Temp/ipykernel_10588/4243699691.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ch["con"][i]=ch['confirmed'][i]-ch['confirmed'][i-1]
# C:\Users\mange\AppData\Local\Temp/ipykernel_10588/4243699691.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ch["rec"][i]=ch['recovered'][i]-ch['recovered'][i-1]
# C:\Users\mange\AppData\Local\Temp/ipykernel_10588/4243699691.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
l1=ch.groupby(['year','month']).sum()
l2=ch.groupby(['year','month']).count()
l3=l1/l2
l3=l3.reset_index(level=['year','month'])
l1=l1.reset_index(level=['year','month'])
l3
# Out:
#     year month        Date  administrative_area_level  \
# 0   2020    01  20200117.0                        1.0
# 1   2020    02  20200215.0                        1.0
# 2   2020    03  20200316.0                        1.0
# 3   2020    04  20200415.5                        1.0
# 4   2020    05  20200516.0                        1.0
# 5   2020    06  20200615.5                        1.0
# 6   2020    07  20200716.0                        1.0
# 7   2020    08  20200816.0                        1.0
# 8   2020    09  20200915.5                        1.0
# 9   2020    10  20201016.0                        1.0
# 10  2020    11  20201115.5                        1.0
# 11  2020    12  20201216.0                        1.0
# 12  2021    01  20210116.0                        1.0
# 13  2021    02  20210214.5                        1.0
# 14  2021    03  20210316.0                        1.0
# 15  2021    04  20210415.5                        1.0
# ...

# %%
xa=np.arange(28)
ya1=l3['school_closing']
ya2=l3['workplace_closing']
ya3=l3['cancel_events']
ya4=l3['gatherings_restrictions']
ya5=l3['transport_closing']
ya6=l3['stay_home_restrictions']
ya7=l3['internal_movement_restrictions']
ya8=l3['international_movement_restrictions']
ya9=l3['information_campaigns']
len(xa)
# Out:
# 28

# %%
z1=ind.groupby(['year','month']).sum()
z2=ind.groupby(['year','month']).count()
z3=z1/z2
z3=z3.reset_index(level=['year','month'])
z1=z1.reset_index(level=['year','month'])
z3
# Out:
#     year month        Date  administrative_area_level  \
# 0   2020    01  20200126.5                        1.0
# 1   2020    02  20200215.0                        1.0
# 2   2020    03  20200316.0                        1.0
# 3   2020    04  20200415.5                        1.0
# 4   2020    05  20200516.0                        1.0
# 5   2020    06  20200615.5                        1.0
# 6   2020    07  20200716.0                        1.0
# 7   2020    08  20200816.0                        1.0
# 8   2020    09  20200915.5                        1.0
# 9   2020    10  20201016.0                        1.0
# 10  2020    11  20201115.5                        1.0
# 11  2020    12  20201216.0                        1.0
# 12  2021    01  20210116.0                        1.0
# 13  2021    02  20210214.5                        1.0
# 14  2021    03  20210316.0                        1.0
# 15  2021    04  20210415.5                        1.0
# ...

# %%
yb1=z3['school_closing']
yb2=z3['workplace_closing']
yb3=z3['cancel_events']
yb4=z3['gatherings_restrictions']
yb5=z3['transport_closing']
yb6=z3['stay_home_restrictions']
yb7=z3['internal_movement_restrictions']
yb8=z3['international_movement_restrictions']
yb9=z3['information_campaigns']

# %%
o1=usa.groupby(['year','month']).sum()
o2=usa.groupby(['year','month']).count()
o3=o1/o2
o3=o3.reset_index(level=['year','month'])
o1=o1.reset_index(level=['year','month'])
o3
# Out:
#     year month        Date  administrative_area_level  \
# 0   2020    01  20200126.0                        1.0
# 1   2020    02  20200215.0                        1.0
# 2   2020    03  20200316.0                        1.0
# 3   2020    04  20200415.5                        1.0
# 4   2020    05  20200516.0                        1.0
# 5   2020    06  20200615.5                        1.0
# 6   2020    07  20200716.0                        1.0
# 7   2020    08  20200816.0                        1.0
# 8   2020    09  20200915.5                        1.0
# 9   2020    10  20201016.0                        1.0
# 10  2020    11  20201115.5                        1.0
# 11  2020    12  20201216.0                        1.0
# 12  2021    01  20210116.0                        1.0
# 13  2021    02  20210214.5                        1.0
# 14  2021    03  20210316.0                        1.0
# 15  2021    04  20210415.5                        1.0
# ...

# %%
yc1=o3['school_closing']
yc2=o3['workplace_closing']
yc3=o3['cancel_events']
yc4=o3['gatherings_restrictions']
yc5=o3['transport_closing']
yc6=o3['stay_home_restrictions']
yc7=o3['internal_movement_restrictions']
yc8=o3['international_movement_restrictions']
yc9=o3['information_campaigns']

# %%
plt.figure(figsize=(15,30))
plt.subplot(9,3,1)
plt.bar(xa,ya1,color='red')
plt.xlabel("Months")
plt.ylabel("school_closing")
plt.subplot(9,3,2)
plt.bar(xa,yb1,color='orange')
plt.xlabel("Months")
plt.ylabel("school_closing")
plt.subplot(9,3,3)
plt.bar(xa,yc1)
plt.xlabel("Months")
plt.ylabel("school_closing")
plt.subplot(9,3,4)
plt.bar(xa,ya2,color='red')
plt.xlabel("Months")
plt.ylabel("workplace_closing")
plt.subplot(9,3,5)
plt.bar(xa,yb2,color='orange')
plt.xlabel("Months")
plt.ylabel("workplace_closing")
plt.subplot(9,3,6)
plt.bar(xa,yc2)
plt.xlabel("Months")
plt.ylabel("workplace_closing")
plt.subplot(9,3,7)
plt.bar(xa,ya3,color='red')
plt.xlabel("Months")
plt.ylabel("cancel_events")
plt.subplot(9,3,8)
plt.bar(xa,yb3,color='orange')
plt.xlabel("Months")
plt.ylabel("cancel_events")
plt.subplot(9,3,9)
plt.bar(xa,yc3)
plt.xlabel("Months")
plt.ylabel("cancel_events")
plt.subplot(9,3,10)
plt.bar(xa,ya4,color='red')
plt.xlabel("Months")
plt.ylabel("gatherings_restrictions")
plt.subplot(9,3,11)
plt.bar(xa,yb4,color='orange')
plt.xlabel("Months")
plt.ylabel("gatherings_restrictions")
plt.subplot(9,3,12)
plt.bar(xa,yc4)
plt.xlabel("Months")
plt.ylabel("gatherings_restrictions")
plt.subplot(9,3,13)
plt.bar(xa,ya5,color='red')
plt.xlabel("Days")
plt.ylabel("transport_closing")
plt.subplot(9,3,14)
plt.bar(xa,yb5,color='orange')
plt.xlabel("Months")
plt.ylabel("transport_closing")
plt.subplot(9,3,15)
plt.bar(xa,yc5)
plt.xlabel("Months")
plt.ylabel("transport_closing")
plt.subplot(9,3,16)
plt.bar(xa,ya6,color='red')
plt.xlabel("Months")
plt.ylabel("stay_home_restrictions")
plt.subplot(9,3,17)
plt.bar(xa,yb6,color='orange')
plt.xlabel("Months")
plt.ylabel("stay_home_restrictions")
plt.subplot(9,3,18)
plt.bar(xa,yc6)
plt.xlabel("Months")
plt.ylabel("stay_home_restrictions")
plt.subplot(9,3,19)
plt.bar(xa,ya7,color='red')
plt.xlabel("Months")
plt.ylabel("internal_movement_restrictions")
plt.subplot(9,3,20)
plt.bar(xa,yb7,color='orange')
plt.xlabel("Months")
plt.ylabel("internal_movement_restrictions")
plt.subplot(9,3,21)
plt.bar(xa,yc7)
plt.xlabel("Months")
plt.ylabel("internal_movement_restrictions")
plt.subplot(9,3,22)
plt.bar(xa,ya8,color='red')
plt.xlabel("Months")
plt.ylabel("international_movement_restrictions")
plt.subplot(9,3,23)
plt.bar(xa,yb8,color='orange')
plt.xlabel("Months")
plt.ylabel("international_movement_restrictions")
plt.subplot(9,3,24)
plt.bar(xa,yc8)
plt.xlabel("Months")
plt.ylabel("international_movement_restrictions")
plt.subplot(9,3,25)
plt.bar(xa,ya9,color='red')
plt.xlabel("Months")
plt.ylabel("information_campaigns")
plt.subplot(9,3,26)
plt.bar(xa,yb9,color='orange')
plt.xlabel("Months")
plt.ylabel("information_campaigns")
plt.subplot(9,3,27)
plt.bar(xa,yc9)
plt.xlabel("Months")
plt.ylabel("information_campaigns")
plt.show()

# %%
xa1=np.arange(28)
yd1=l1['con']
yd2=z1['con']
yd3=o1['con']

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.bar(xa1,yd1,color='red')
plt.xlabel("Months")
plt.ylabel("CONFIRMED CHINA")
plt.subplot(1,3,2)
plt.bar(xa1,yd2,color='orange')
plt.xlabel("Months")
plt.ylabel("CONFIRMED INDIA")
plt.subplot(1,3,3)
plt.bar(xa1,yd3)
plt.xlabel("Months")
plt.ylabel("CONFIRMED USA")
# Out:
# Text(0, 0.5, 'CONFIRMED USA')

# %%
xa1=np.arange(28)
yd1=l1['rec']
yd2=z1['rec']
yd3=o1['rec']

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.bar(xa1,yd1,color='red')
plt.xlabel("Months")
plt.ylabel("RECOVERED CHINA")
plt.subplot(1,3,2)
plt.bar(xa1,yd2,color='orange')
plt.xlabel("Months")
plt.ylabel("RECOVERED INDIA ")
plt.subplot(1,3,3)
plt.bar(xa1,yd3)
plt.xlabel("Months")
plt.ylabel("RECOVERED USA")
# Out:
# Text(0, 0.5, 'RECOVERED USA')

# %%
xa1=np.arange(28)
yd1=l1['det']
yd2=z1['det']
yd3=o1['det']
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.bar(xa1,yd1,color='red')
plt.xlabel("Months")
plt.ylabel("death CHINA")
plt.subplot(1,3,2)
plt.bar(xa1,yd2,color='orange')
plt.xlabel("Months")
plt.ylabel("death INDIA ")
plt.subplot(1,3,3)
plt.bar(xa1,yd3)
plt.xlabel("Months")
plt.ylabel("death USA")
# Out:
# Text(0, 0.5, 'death USA')

# %%
ud1=usa['deaths'].groupby(df['Date']).sum()
id1=ind['deaths'].groupby(df['Date']).sum()
ch1=ch['deaths'].groupby(df['Date']).sum()
ud2=usa['recovered'].groupby(df['Date']).sum()
id2=ind['recovered'].groupby(df['Date']).sum()
ch2=ch['recovered'].groupby(df['Date']).sum()
ud3=usa['contact_tracing'].groupby(df['Date']).sum()
id3=ind['contact_tracing'].groupby(df['Date']).sum()
ch3=ch['contact_tracing'].groupby(df['Date']).sum()
ud4=usa['people_vaccinated'].groupby(df['Date']).sum()
id4=ind['people_vaccinated'].groupby(df['Date']).sum()
ch4=ch['people_vaccinated'].groupby(df['Date']).sum()
ud5=usa['people_fully_vaccinated'].groupby(df['Date']).sum()
id5=ind['people_fully_vaccinated'].groupby(df['Date']).sum()
ch5=ch['people_fully_vaccinated'].groupby(df['Date']).sum()

# %%
plt.figure(figsize=(20,20))
plt.subplot(3,2,1)
data=list([ch1,id1,ud1])
plt.boxplot(data)
plt.xlabel("CHINA    vs   INDIA    vs  USA")
plt.ylabel("deaths")
plt.subplot(3,2,2)
data=list([ch2,id2,ud2])
plt.boxplot(data)
plt.xlabel("CHINA    vs   INDIA    vs  USA")
plt.ylabel("recovered")
plt.subplot(3,2,3)
data=list([ch3,id3,ud3])
plt.boxplot(data)
plt.xlabel("CHINA    vs   INDIA    vs  USA")
plt.ylabel("contact_tracing")
plt.subplot(3,2,4)
data=list([ch4,id4,ud4])
plt.boxplot(data)
plt.xlabel("CHINA    vs   INDIA    vs  USA")
plt.ylabel("people_vaccinated")
plt.subplot(3,2,5)
data=list([ch5,id5,ud5])
plt.boxplot(data)
plt.xlabel("CHINA    vs   INDIA    vs  USA")
plt.ylabel("people_fully_vaccinated")
plt.show()

# %%
ch
# Out:
#      index        id        date  confirmed   deaths  recovered       tests  \
# 0    92412  78833522  2020-01-03        0.0      0.0        1.0  90000000.0
# 1    92413  78833522  2020-01-04        1.0      0.0        1.0  90000000.0
# 2    92414  78833522  2020-01-05        1.0      0.0        1.0  90000000.0
# 3    92415  78833522  2020-01-06        4.0      0.0        1.0  90000000.0
# 4    92416  78833522  2020-01-07        4.0      0.0        1.0  90000000.0
# ..     ...       ...         ...        ...      ...        ...         ...
# 833  93245  78833522  2022-04-15   959392.0  14494.0        1.0    129291.0
# 834  93246  78833522  2022-04-16   965042.0  14561.0        1.0    129291.0
# 835  93247  78833522  2022-04-17   970368.0  14602.0        1.0    129291.0
# 836  93248  78833522  2022-04-18   974858.0  14634.0        1.0    129291.0
# 837  93249  78833522  2022-04-19   979966.0  14661.0        1.0    129291.0
#
# ...

# %%
z1['rec']
# Out:
# 0            3.0
# 1            1.0
# 2          119.0
# 3         8945.0
# 4        82784.0
# 5       256060.0
# 6       746462.0
# 7      1745508.0
# 8      2433319.0
# 9      2218312.0
# 10     1398072.0
# 11      993876.0
# 12      551522.0
# 13      351469.0
# 14      688231.0
# 15     4209723.0
# 16    10263223.0
# 17     3541289.0
# 18     1331603.0
# 19   -30820520.0
# 20           0.0
# 21           0.0
# 22           0.0
# 23           0.0
# 24           0.0
# 25           0.0
# 26           0.0
# 27           0.0
# Name: rec, dtype: float64

# %%
xa1=np.arange(28)
yd4=l1['vac']
yd5=z1['vac']
yd6=o1['vac']

plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.bar(xa1,yd4,color='red')
plt.xlabel("Months")
plt.ylabel("fully vaccinated CHINA")
plt.subplot(1,3,2)
plt.bar(xa1,yd5,color='orange')
plt.xlabel("Months")
plt.ylabel("fully vaccinated INDIA")
plt.subplot(1,3,3)
plt.bar(xa1,yd6)
plt.xlabel("Months")
plt.ylabel("fully vaccinated USA")
# Out:
# Text(0, 0.5, 'fully vaccinated USA')
